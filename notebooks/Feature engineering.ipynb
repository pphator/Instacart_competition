# %%
import pandas as pd

# %%
data_path = '..\\data\\'

# %% [markdown]
# Чтение данных из CSV файлов

# %%
orders = pd.read_csv(data_path + 'orders.csv' )
order_products_train = pd.read_csv(data_path + 'order_products__train.csv')
order_products_prior = pd.read_csv(data_path + 'order_products__prior.csv')
products = pd.read_csv(data_path + 'products.csv')
aisles = pd.read_csv(data_path + 'aisles.csv')
departments = pd.read_csv(data_path + 'departments.csv')

# %% [markdown]
# Перевод полей типа "Object" в категориальный тип

# %%
aisles['aisle'] = aisles['aisle'].astype('category')
departments['department'] = departments['department'].astype('category')
orders['eval_set'] = orders['eval_set'].astype('category')
products['product_name'] = products['product_name'].astype('category')

# %% [markdown]
# Создание объекта DataFrame с заказами и соответствующими продуктами из prior части набора данных для генерации признаков

# %%
proir_orders_df = orders.merge(order_products_prior, on='order_id', how='inner')
proir_orders_df.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0

# %% [markdown]
# ### Подготовка признаков / Feature engineering

# %% [markdown]
# #### Признаки, относящиеся к пользователям

# %% [markdown]
# Размер последнего заказа пользователя

# %%
proir_orders_df.groupby(['user_id'])['order_number'].max().reset_index()
# Out:
#         user_id  order_number
# 0             1            10
# 1             2            14
# 2             3            12
# 3             4             5
# 4             5             4
# ...         ...           ...
# 206204   206205             3
# 206205   206206            67
# 206206   206207            16
# 206207   206208            49
# 206208   206209            13
#
# [206209 rows x 2 columns]

# %%
last_orders = proir_orders_df.merge(proir_orders_df.groupby(['user_id'])['order_number'].max().reset_index(), how='inner', left_on=['user_id', 'order_number'], right_on=['user_id', 'order_number'])

# %%
last_orders_df = last_orders.groupby(['user_id']).size().to_frame('last_order_size').reset_index()

# %% [markdown]
# Число заказов у пользователей

# %%
users_info = proir_orders_df.groupby('user_id')['order_number'].max().to_frame('u_total_orders').reset_index()
users_info.head()
# Out:
#    user_id  u_total_orders
# 0        1              10
# 1        2              14
# 2        3              12
# 3        4               5
# 4        5               4

# %% [markdown]
# Как часто пользователь перезаказывал продукты

# %%
user_reorder_ratio = proir_orders_df.groupby('user_id')['reordered'].mean().to_frame('u_reordered_ratio').reset_index()
user_reorder_ratio.head()
# Out:
#    user_id  u_reordered_ratio
# 0        1           0.694915
# 1        2           0.476923
# 2        3           0.625000
# 3        4           0.055556
# 4        5           0.378378

# %%
users_info = users_info.merge(user_reorder_ratio, on='user_id', how='left')

# %%
users_info.head()
# Out:
#    user_id  u_total_orders  u_reordered_ratio
# 0        1              10           0.694915
# 1        2              14           0.476923
# 2        3              12           0.625000
# 3        4               5           0.055556
# 4        5               4           0.378378

# %%
users_info = users_info.merge(last_orders_df, on='user_id', how='left')

# %%
users_info.head()
# Out:
#    user_id  u_total_orders  u_reordered_ratio  last_order_size
# 0        1              10           0.694915                9
# 1        2              14           0.476923               16
# 2        3              12           0.625000                6
# 3        4               5           0.055556                3
# 4        5               4           0.378378               12

# %% [markdown]
# #### Признаки относящиеся к продуктам

# %% [markdown]
# Число заказов каждого продукта

# %%
items_info = proir_orders_df.groupby('product_id')['order_id'].count().to_frame('items_total_purchases').reset_index()
items_info.head()
# Out:
#    product_id  items_total_purchases
# 0           1                   1852
# 1           2                     90
# 2           3                    277
# 3           4                    329
# 4           5                     15

# %% [markdown]
# Вероятность продукта быть заказанным повторно

# %%
min_items_threshold = 40
items_reorder = proir_orders_df.groupby('product_id').filter(lambda x: x.shape[0] > min_items_threshold)
items_reorder.head()
# Out:
#    order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0   2539329        1    prior             1          2                  8
# 1   2539329        1    prior             1          2                  8
# 2   2539329        1    prior             1          2                  8
# 3   2539329        1    prior             1          2                  8
# 4   2539329        1    prior             1          2                  8
#
#    days_since_prior_order  product_id  add_to_cart_order  reordered
# 0                     NaN         196                  1          0
# 1                     NaN       14084                  2          0
# 2                     NaN       12427                  3          0
# 3                     NaN       26088                  4          0
# 4                     NaN       26405                  5          0

# %%
items_reorder = items_reorder.groupby('product_id')['reordered'].mean().to_frame('items_reorder_ratio').reset_index()
items_reorder.head()
# Out:
#    product_id  items_reorder_ratio
# 0           1             0.613391
# 1           2             0.133333
# 2           3             0.732852
# 3           4             0.446809
# 4           8             0.503030

# %% [markdown]
# Объединим признаки

# %%
items_info = items_info.merge(items_reorder, on='product_id', how='left')

# %%
items_info['items_reorder_ratio'] = items_info['items_reorder_ratio'].fillna(value=0)
items_info.head()
# Out:
#    product_id  items_total_purchases  items_reorder_ratio
# 0           1                   1852             0.613391
# 1           2                     90             0.133333
# 2           3                    277             0.732852
# 3           4                    329             0.446809
# 4           5                     15             0.000000

# %% [markdown]
# Признаки пары пользователь-продукт

# %% [markdown]
# Как часто пользователь заказывал конкретный продукт

# %%
items_per_users = proir_orders_df.groupby(['user_id', 'product_id'])['order_id'].count().to_frame('ipu_total_bought').reset_index()
items_per_users.head()
# Out:
#    user_id  product_id  ipu_total_bought
# 0        1         196                10
# 1        1       10258                 9
# 2        1       10326                 1
# 3        1       12427                10
# 4        1       13032                 3

# %% [markdown]
# Как часто пользователь заказывал продукт после своего первого заказа

# %% [markdown]
# Для этого поделим число заказов с покупкой этого продукта на число заказов с того момента, как пользователь купил продукт первый раз

# %%
times = proir_orders_df.groupby(['user_id', 'product_id'])[['order_id']].count()
times.columns = ['times_bought_n']
times.head()
# Out:
#                     Times_Bought_N
# user_id product_id
# 1       196                     10
#         10258                    9
#         10326                    1
#         12427                   10
#         13032                    3

# %%
total_orders = proir_orders_df.groupby('user_id')['order_number'].max().to_frame('total_orders')
total_orders.head()
# Out:
#          total_orders
# user_id
# 1                  10
# 2                  14
# 3                  12
# 4                   5
# 5                   4

# %%
first_order_no = proir_orders_df.groupby(['user_id', 'product_id'])['order_number'].min().to_frame('first_order_number')
first_order_no  = first_order_no.reset_index()
first_order_no.head()
# Out:
#    user_id  product_id  first_order_number
# 0        1         196                   1
# 1        1       10258                   2
# 2        1       10326                   5
# 3        1       12427                   1
# 4        1       13032                   2

# %%
span = pd.merge(total_orders, first_order_no, on='user_id', how='right')
span.head()
# Out:
#    user_id  total_orders  product_id  first_order_number
# 0        1            10         196                   1
# 1        1            10       10258                   2
# 2        1            10       10326                   5
# 3        1            10       12427                   1
# 4        1            10       13032                   2

# %%
span['order_range_d'] = span.total_orders - span.first_order_number + 1
span.head()
# Out:
#    user_id  total_orders  product_id  first_order_number  Order_Range_D
# 0        1            10         196                   1             10
# 1        1            10       10258                   2              9
# 2        1            10       10326                   5              6
# 3        1            10       12427                   1             10
# 4        1            10       13032                   2              9

# %%
uxp_ratio = pd.merge(times, span, on=['user_id', 'product_id'], how='left')
uxp_ratio.head()
# Out:
#    user_id  product_id  Times_Bought_N  total_orders  first_order_number  \
# 0        1         196              10            10                   1
# 1        1       10258               9            10                   2
# 2        1       10326               1            10                   5
# 3        1       12427              10            10                   1
# 4        1       13032               3            10                   2
#
#    Order_Range_D
# 0             10
# 1              9
# 2              6
# 3             10
# 4              9

# %%
uxp_ratio['uxp_reorder_ratio'] = uxp_ratio['times_bought_n'] / uxp_ratio['order_range_d]
uxp_ratio.head()
# Out:
#    user_id  product_id  Times_Bought_N  total_orders  first_order_number  \
# 0        1         196              10            10                   1
# 1        1       10258               9            10                   2
# 2        1       10326               1            10                   5
# 3        1       12427              10            10                   1
# 4        1       13032               3            10                   2
#
#    Order_Range_D  uxp_reorder_ratio
# 0             10           1.000000
# 1              9           1.000000
# 2              6           0.166667
# 3             10           1.000000
# 4              9           0.333333

# %%
uxp_ratio = uxp_ratio.drop(['times_bought_n', 'total_orders', 'first_order_number', 'order_range_d'], axis=1)
uxp_ratio.head()
# Out:
#    user_id  product_id  uxp_reorder_ratio
# 0        1         196           1.000000
# 1        1       10258           1.000000
# 2        1       10326           0.166667
# 3        1       12427           1.000000
# 4        1       13032           0.333333

# %%
items_per_users = items_per_users.merge(uxp_ratio, on=['user_id', 'product_id'], how='left')
items_per_users.head()
# Out:
#    user_id  product_id  ipu_total_bought  uxp_reorder_ratio
# 0        1         196                10           1.000000
# 1        1       10258                 9           1.000000
# 2        1       10326                 1           0.166667
# 3        1       12427                10           1.000000
# 4        1       13032                 3           0.333333

# %% [markdown]
# Сколько раз пользователь купил продукт за последние пять заказов

# %%
proir_orders_df['order_number_back'] = proir_orders_df.groupby('user_id')['order_number'].transform(max) - proir_orders_df.order_number +1 
proir_orders_df.head(15)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 0    2539329        1    prior             1          2                  8
# 1    2539329        1    prior             1          2                  8
# 2    2539329        1    prior             1          2                  8
# 3    2539329        1    prior             1          2                  8
# 4    2539329        1    prior             1          2                  8
# 5    2398795        1    prior             2          3                  7
# 6    2398795        1    prior             2          3                  7
# 7    2398795        1    prior             2          3                  7
# 8    2398795        1    prior             2          3                  7
# 9    2398795        1    prior             2          3                  7
# 10   2398795        1    prior             2          3                  7
# 11    473747        1    prior             3          3                 12
# 12    473747        1    prior             3          3                 12
# 13    473747        1    prior             3          3                 12
# 14    473747        1    prior             3          3                 12
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 0                      NaN         196                  1          0
# 1                      NaN       14084                  2          0
# 2                      NaN       12427                  3          0
# 3                      NaN       26088                  4          0
# 4                      NaN       26405                  5          0
# 5                     15.0         196                  1          1
# 6                     15.0       10258                  2          0
# 7                     15.0       12427                  3          1
# 8                     15.0       13176                  4          0
# 9                     15.0       26088                  5          1
# 10                    15.0       13032                  6          0
# 11                    21.0         196                  1          1
# 12                    21.0       12427                  2          1
# 13                    21.0       10258                  3          1
# 14                    21.0       25133                  4          0
#
#     order_number_back
# 0                  10
# 1                  10
# 2                  10
# 3                  10
# 4                  10
# 5                   9
# 6                   9
# 7                   9
# 8                   9
# 9                   9
# 10                  9
# 11                  8
# 12                  8
# 13                  8
# 14                  8

# %%
five_proir_orders_df = proir_orders_df[proir_orders_df.order_number_back <= 5]
five_proir_orders_df.head(15)
# Out:
#     order_id  user_id eval_set  order_number  order_dow  order_hour_of_day  \
# 29   3367565        1    prior             6          2                  7
# 30   3367565        1    prior             6          2                  7
# 31   3367565        1    prior             6          2                  7
# 32   3367565        1    prior             6          2                  7
# 33    550135        1    prior             7          1                  9
# 34    550135        1    prior             7          1                  9
# 35    550135        1    prior             7          1                  9
# 36    550135        1    prior             7          1                  9
# 37    550135        1    prior             7          1                  9
# 38   3108588        1    prior             8          1                 14
# 39   3108588        1    prior             8          1                 14
# 40   3108588        1    prior             8          1                 14
# 41   3108588        1    prior             8          1                 14
# 42   3108588        1    prior             8          1                 14
# 43   3108588        1    prior             8          1                 14
#
#     days_since_prior_order  product_id  add_to_cart_order  reordered  \
# 29                    19.0         196                  1          1
# 30                    19.0       12427                  2          1
# 31                    19.0       10258                  3          1
# 32                    19.0       25133                  4          1
# 33                    20.0         196                  1          1
# 34                    20.0       10258                  2          1
# 35                    20.0       12427                  3          1
# 36                    20.0       25133                  4          1
# 37                    20.0       13032                  5          1
# 38                    14.0       12427                  1          1
# 39                    14.0         196                  2          1
# 40                    14.0       10258                  3          1
# 41                    14.0       25133                  4          1
# 42                    14.0       46149                  5          0
# 43                    14.0       49235                  6          0
#
#     order_number_back
# 29                  5
# 30                  5
# 31                  5
# 32                  5
# 33                  4
# 34                  4
# 35                  4
# 36                  4
# 37                  4
# 38                  3
# 39                  3
# 40                  3
# 41                  3
# 42                  3
# 43                  3

# %%
last_five = five_proir_orders_df.groupby(['user_id','product_id'])[['order_id']].count()
last_five.columns = ['times_last5']
last_five.head(10)
# Out:
#                     times_last5
# user_id product_id
# 1       196                   5
#         10258                 5
#         12427                 5
#         13032                 2
#         25133                 5
#         35951                 1
#         38928                 1
#         39657                 1
#         46149                 3
#         49235                 2

# %%
items_per_users = items_per_users.merge(last_five, on=['user_id', 'product_id'], how='left')

# %%
items_per_users = items_per_users.fillna(0)

# %% [markdown]
# Объединим все признаки

# %%
data_df = items_per_users.merge(users_info, on='user_id', how='left')
data_df.head()
# Out:
#    user_id  product_id  ipu_total_bought  uxp_reorder_ratio  times_last5  \
# 0        1         196                10           1.000000          5.0
# 1        1       10258                 9           1.000000          5.0
# 2        1       10326                 1           0.166667          0.0
# 3        1       12427                10           1.000000          5.0
# 4        1       13032                 3           0.333333          2.0
#
#    u_total_orders  u_reordered_ratio  last_order_size
# 0              10           0.694915                9
# 1              10           0.694915                9
# 2              10           0.694915                9
# 3              10           0.694915                9
# 4              10           0.694915                9

# %%
data_df = data_df.merge(items_info, on='product_id', how='left')
data_df.head()
# Out:
#    user_id  product_id  ipu_total_bought  uxp_reorder_ratio  times_last5  \
# 0        1         196                10           1.000000          5.0
# 1        1       10258                 9           1.000000          5.0
# 2        1       10326                 1           0.166667          0.0
# 3        1       12427                10           1.000000          5.0
# 4        1       13032                 3           0.333333          2.0
#
#    u_total_orders  u_reordered_ratio  last_order_size  items_total_purchases  \
# 0              10           0.694915                9                  35791
# 1              10           0.694915                9                   1946
# 2              10           0.694915                9                   5526
# 3              10           0.694915                9                   6476
# 4              10           0.694915                9                   3751
#
#    items_reorder_ratio
# 0             0.776480
# 1             0.713772
# 2             0.652009
# 3             0.740735
# 4             0.657158

# %%
orders_future = orders[((orders.eval_set=='train') | (orders.eval_set=='test'))]
orders_future = orders_future[ ['user_id', 'eval_set', 'order_id'] ]

# %%
data_df = data_df.merge(orders_future, on='user_id', how='left')
data_df.head(10)
# Out:
#    user_id  product_id  ipu_total_bought  uxp_reorder_ratio  times_last5  \
# 0        1         196                10           1.000000          5.0
# 1        1       10258                 9           1.000000          5.0
# 2        1       10326                 1           0.166667          0.0
# 3        1       12427                10           1.000000          5.0
# 4        1       13032                 3           0.333333          2.0
# 5        1       13176                 2           0.222222          0.0
# 6        1       14084                 1           0.100000          0.0
# 7        1       17122                 1           0.166667          0.0
# 8        1       25133                 8           1.000000          5.0
# 9        1       26088                 2           0.200000          0.0
#
#    u_total_orders  u_reordered_ratio  last_order_size  items_total_purchases  \
# 0              10           0.694915                9                  35791
# 1              10           0.694915                9                   1946
# 2              10           0.694915                9                   5526
# 3              10           0.694915                9                   6476
# 4              10           0.694915                9                   3751
# 5              10           0.694915                9                 379450
# 6              10           0.694915                9                  15935
# 7              10           0.694915                9                  13880
# 8              10           0.694915                9                   6196
# 9              10           0.694915                9                   2523
#
#    items_reorder_ratio eval_set  order_id
# 0             0.776480    train   1187899
# 1             0.713772    train   1187899
# 2             0.652009    train   1187899
# 3             0.740735    train   1187899
# 4             0.657158    train   1187899
# 5             0.832555    train   1187899
# 6             0.810982    train   1187899
# 7             0.675576    train   1187899
# 8             0.740155    train   1187899
# 9             0.539041    train   1187899

# %%
data_train = data_df[data_df['eval_set'] == 'train']
data_train.head()
# Out:
#    user_id  product_id  ipu_total_bought  uxp_reorder_ratio  times_last5  \
# 0        1         196                10           1.000000          5.0
# 1        1       10258                 9           1.000000          5.0
# 2        1       10326                 1           0.166667          0.0
# 3        1       12427                10           1.000000          5.0
# 4        1       13032                 3           0.333333          2.0
#
#    u_total_orders  u_reordered_ratio  last_order_size  items_total_purchases  \
# 0              10           0.694915                9                  35791
# 1              10           0.694915                9                   1946
# 2              10           0.694915                9                   5526
# 3              10           0.694915                9                   6476
# 4              10           0.694915                9                   3751
#
#    items_reorder_ratio eval_set  order_id
# 0             0.776480    train   1187899
# 1             0.713772    train   1187899
# 2             0.652009    train   1187899
# 3             0.740735    train   1187899
# 4             0.657158    train   1187899

# %%
data_train = data_train.merge(order_products_train[['product_id','order_id', 'reordered']], on=['product_id','order_id'], how='left' )
data_train.head(15)
# Out:
#     user_id  product_id  ipu_total_bought  uxp_reorder_ratio  times_last5  \
# 0         1         196                10           1.000000          5.0
# 1         1       10258                 9           1.000000          5.0
# 2         1       10326                 1           0.166667          0.0
# 3         1       12427                10           1.000000          5.0
# 4         1       13032                 3           0.333333          2.0
# 5         1       13176                 2           0.222222          0.0
# 6         1       14084                 1           0.100000          0.0
# 7         1       17122                 1           0.166667          0.0
# 8         1       25133                 8           1.000000          5.0
# 9         1       26088                 2           0.200000          0.0
# 10        1       26405                 2           0.200000          0.0
# 11        1       30450                 1           0.125000          0.0
# 12        1       35951                 1           1.000000          1.0
# 13        1       38928                 1           1.000000          1.0
# 14        1       39657                 1           1.000000          1.0
#
#     u_total_orders  u_reordered_ratio  last_order_size  items_total_purchases  \
# 0               10           0.694915                9                  35791
# 1               10           0.694915                9                   1946
# 2               10           0.694915                9                   5526
# 3               10           0.694915                9                   6476
# 4               10           0.694915                9                   3751
# 5               10           0.694915                9                 379450
# 6               10           0.694915                9                  15935
# 7               10           0.694915                9                  13880
# 8               10           0.694915                9                   6196
# 9               10           0.694915                9                   2523
# 10              10           0.694915                9                   1214
# 11              10           0.694915                9                  21490
# 12              10           0.694915                9                  57895
# 13              10           0.694915                9                  13238
# 14              10           0.694915                9                   5019
#
#     items_reorder_ratio eval_set  order_id  reordered
# 0              0.776480    train   1187899        1.0
# 1              0.713772    train   1187899        1.0
# 2              0.652009    train   1187899        NaN
# 3              0.740735    train   1187899        NaN
# 4              0.657158    train   1187899        1.0
# 5              0.832555    train   1187899        NaN
# 6              0.810982    train   1187899        NaN
# 7              0.675576    train   1187899        NaN
# 8              0.740155    train   1187899        1.0
# 9              0.539041    train   1187899        1.0
# 10             0.441516    train   1187899        1.0
# 11             0.566682    train   1187899        NaN
# 12             0.757837    train   1187899        NaN
# 13             0.827769    train   1187899        1.0
# 14             0.766288    train   1187899        1.0

# %%
data_train['reordered'] = data_train['reordered'].fillna(0)
data_train.head(5)
# Out:
#    user_id  product_id  ipu_total_bought  uxp_reorder_ratio  times_last5  \
# 0        1         196                10           1.000000          5.0
# 1        1       10258                 9           1.000000          5.0
# 2        1       10326                 1           0.166667          0.0
# 3        1       12427                10           1.000000          5.0
# 4        1       13032                 3           0.333333          2.0
#
#    u_total_orders  u_reordered_ratio  last_order_size  items_total_purchases  \
# 0              10           0.694915                9                  35791
# 1              10           0.694915                9                   1946
# 2              10           0.694915                9                   5526
# 3              10           0.694915                9                   6476
# 4              10           0.694915                9                   3751
#
#    items_reorder_ratio eval_set  order_id  reordered
# 0             0.776480    train   1187899        1.0
# 1             0.713772    train   1187899        1.0
# 2             0.652009    train   1187899        0.0
# 3             0.740735    train   1187899        0.0
# 4             0.657158    train   1187899        1.0

# %%
data_train = data_train.drop(['eval_set', 'order_id'], axis=1)
data_train.head(5)
# Out:
#    user_id  product_id  ipu_total_bought  uxp_reorder_ratio  times_last5  \
# 0        1         196                10           1.000000          5.0
# 1        1       10258                 9           1.000000          5.0
# 2        1       10326                 1           0.166667          0.0
# 3        1       12427                10           1.000000          5.0
# 4        1       13032                 3           0.333333          2.0
#
#    u_total_orders  u_reordered_ratio  last_order_size  items_total_purchases  \
# 0              10           0.694915                9                  35791
# 1              10           0.694915                9                   1946
# 2              10           0.694915                9                   5526
# 3              10           0.694915                9                   6476
# 4              10           0.694915                9                   3751
#
#    items_reorder_ratio  reordered
# 0             0.776480        1.0
# 1             0.713772        1.0
# 2             0.652009        0.0
# 3             0.740735        0.0
# 4             0.657158        1.0

# %%
data_test = data_df[data_df['eval_set'] == 'test']
data_test.head()
# Out:
#      user_id  product_id  ipu_total_bought  uxp_reorder_ratio  times_last5  \
# 120        3         248                 1           0.090909          0.0
# 121        3        1005                 1           0.333333          1.0
# 122        3        1819                 3           0.333333          0.0
# 123        3        7503                 1           0.100000          0.0
# 124        3        8021                 1           0.090909          0.0
#
#      u_total_orders  u_reordered_ratio  last_order_size  \
# 120              12              0.625                6
# 121              12              0.625                6
# 122              12              0.625                6
# 123              12              0.625                6
# 124              12              0.625                6
#
#      items_total_purchases  items_reorder_ratio eval_set  order_id
# 120                   6371             0.400251     test   2774568
# 121                    463             0.440605     test   2774568
# 122                   2424             0.492162     test   2774568
# 123                  12474             0.553551     test   2774568
# 124                  27864             0.591157     test   2774568

# %%
data_test = data_test.drop(['eval_set','order_id'], axis=1)

# %% [markdown]
# Сохраним датасеты в формате CSV для отдельной разработки модели

# %%
data_train.to_csv(data_path + 'train_val_dataset.csv', index=False)

# %%
data_test.to_csv(data_path + 'test_dataset.csv', index=False)
